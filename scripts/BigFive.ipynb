# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.pre_post_loader import pre_post_reader, get_pre_post_difference

# %% [markdown]
# # Data Processing
# ## 1. Read data
# - Data missing (40 uids)

# %%
data_path = '/Users/catherine/AI/UoA/T6/RA/code/StudentLife/data/dataset/survey/BigFive.csv'
# define a mapping function
mapping_rule = {
        'Disagree Strongly': int(1), #handle edge case
        'Disagree strongly': int(1),
        'Disagree a little': int(2),
        'Neither agree nor disagree': int(3),
        'Agree a little': int(4),
        'Agree strongly': int(5)
    }
# Remove the row wtih NaN value
df, pre_df, post_df = pre_post_reader(data_path, mode='remove', mapping=mapping_rule, to_int=True)
# Out:
# /Users/catherine/AI/UoA/T6/RA/code/StudentLife/src/pre_post_loader.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[col_names[2:]] = new_df.loc[:, col_names[2:]].astype('int64')

# %%
df.head()
# Out:
#    uid type  I see myself as someone who...   - 1. Is talkative  \
# 0  u00  pre                                                  4
# 1  u01  pre                                                  3
# 2  u02  pre                                                  2
# 3  u03  pre                                                  2
# 4  u04  pre                                                  2
#
#    I see myself as someone who...   - 2. Tends to find fault with others  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    I see myself as someone who...   - 3. Does a thorough job  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# ...

# %%
pre_df['I see myself as someone who...   - 1. Is talkative'].unique()
# Out:
# array([4, 3, 2, 1, 5])

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 45
# Data columns (total 46 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   uid                                                                                   31 non-null     object
#  1   type                                                                                  31 non-null     object
#  2   I see myself as someone who...   - 1. Is talkative                                    31 non-null     int64
#  3   I see myself as someone who...   - 2. Tends to find fault with others                 31 non-null     int64
#  4   I see myself as someone who...   - 3. Does a thorough job                             31 non-null     int64
# ...

# %%
post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 46 to 84
# Data columns (total 46 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   uid                                                                                   31 non-null     object
#  1   type                                                                                  31 non-null     object
#  2   I see myself as someone who...   - 1. Is talkative                                    31 non-null     int64
#  3   I see myself as someone who...   - 2. Tends to find fault with others                 31 non-null     int64
#  4   I see myself as someone who...   - 3. Does a thorough job                             31 non-null     int64
# ...

# %%
pos = [
    'I see myself as someone who...   - 1. Is talkative',
    'I see myself as someone who...   - 3. Does a thorough job',
    'I see myself as someone who...   - 5. Is original, comes up with new ideas',
    'I see myself as someone who...   - 7. Is helpful and unselfish with others',
    'I see myself as someone who...   - 9. Is relaxed, handles stress well.',
    'I see myself as someone who...   - 10. Is curious about many different things',
    'I see myself as someone who...   - 11.Is full of energy',
    'I see myself as someone who...   - 13. Is a reliable worker',
    'I see myself as someone who...   - 15. Is ingenious, a deep thinker',
    'I see myself as someone who...   - 16. Generates a lot of enthusiasm',
    'I see myself as someone who...   - 17. Has a forgiving nature',
    'I see myself as someone who...   - 20. Has an active imagination',
    'I see myself as someone who...   - 22. Is generally trusting',
    'I see myself as someone who...   - 24. Is emotionally stable, not easily upset',
    'I see myself as someone who...   - 25. Is inventive',
    'I see myself as someone who...   - 26. Has an assertive personality',
    'I see myself as someone who...   - 28. Perseveres until the task is finished',
    'I see myself as someone who...   - 30. Values artistic, aesthetic experiences',
    'I see myself as someone who...   - 32. Is considerate and kind to almost everyone',
    'I see myself as someone who...   - 33. Does things efficiently',
    'I see myself as someone who...   - 34. Remains calm in tense situations',
    'I see myself as someone who...   - 36. Is outgoing, sociable',
    'I see myself as someone who...   - 38. Makes plans and follows through with them',
    'I see myself as someone who...   - 40. Likes to reflect, play with ideas',
    'I see myself as someone who...   - 42. Likes to cooperate with others',
    'I see myself as someone who...   - 44. Is sophisticated in art, music, or literature'
    ]
neg = [
    'I see myself as someone who...   - 2. Tends to find fault with others',
    'I see myself as someone who...   - 4. Is depressed, blue',
    'I see myself as someone who...   - 6. Is reserved',
    'I see myself as someone who...   - 8. Can be somewhat careless',
    'I see myself as someone who...   - 12. Starts quarrels with others',
    'I see myself as someone who...   - 14. Can be tense',
    'I see myself as someone who...   - 18. Tends to be disorganized',
    'I see myself as someone who...   - 19. Worries a lot',
    'I see myself as someone who...   - 21. Tends to be quiet',
    'I see myself as someone who...   - 23. Tends to be lazy',
    'I see myself as someone who...   - 27. Can be cold and aloof',
    'I see myself as someone who...   - 29. Can be moody',
    'I see myself as someone who...   - 31. Is sometimes shy, inhibited',
    'I see myself as someone who...   - 35. Prefers work that is routine',
    'I see myself as someone who...   - 37. Is sometimes rude to others',
    'I see myself as someone who...   - 39. Gets nervous easily',
    'I see myself as someone who...   - 41. Has few artistic interests',
    'I see myself as someone who...   - 43. Is easily distracted',
]

# %%
col_names = pre_df.columns[2:]
diff_df = get_pre_post_difference(pre_df, post_df, col_names,'BigFive')
diff_df.head()
# Out:
# Check uid matching in the pre and post df: True
#      BigFive_pre  BigFive_post  BigFive_delta
# uid
# u47          159           129             30
# u24          145           167             22
# u45          132           145             13
# u33          151           164             13
# u20          155           143             12
