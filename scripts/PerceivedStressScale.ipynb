# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.pre_post_loader import pre_post_reader, get_pre_post_difference, get_pos_neg_difference, get_status

# %% [markdown]
# # Data Processing
# ## 1. Read data
# - Data missing (40 uids)

# %%
data_path = '/Users/catherine/AI/UoA/T6/RA/code/StudentLife/data/dataset/survey/PerceivedStressScale.csv'
# define a mapping function
mapping_rule = {
        'Never': int(0),
        'Almost never': int(1),
        'Sometime': int(2),
        'Fairly often': int(3),
        'Very often': int(4)
    }
# Remove the row wtih NaN value
df, pre_df, post_df = pre_post_reader(data_path, mode='remove', mapping=mapping_rule,to_int=True)
# Out:
# /Users/catherine/AI/UoA/T6/RA/code/StudentLife/src/pre_post_loader.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[col_names[2:]] = new_df.loc[:, col_names[2:]].astype('int64')

# %%
df.head()
# Out:
#    uid type  \
# 0  u00  pre
# 1  u01  pre
# 2  u02  pre
# 3  u03  pre
# 4  u04  pre
#
#    1. In the last month, how often have you been upset because of something that happened unexpectedly?  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  2
# 4                                                  1
#
#    2. In the last month, how often have you felt that you were unable to control the important things in your life?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    3. In the last month, how often have you felt nervous and "stressed"?  \
# 0                                                  3
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    4. In the last month, how often have you felt confident about your ability to handle your personal problems?  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  1
# 4                                                  2
#
#    5. In the last month, how often have you felt that things were going your way?  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    6. In the last month, how often have you found that you could not cope with all the things that you had to do?  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  3
#
#    7. In the last month, how often have you been able to control irritations in your life?  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    8. In the last month, how often have you felt that you were on top of things?  \
# 0                                                  2
# 1                                                  3
# 2                                                  2
# 3                                                  0
# 4                                                  1
#
#    9. In the last month, how often have you been angered because of things that were outside of your control?  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  0
# 4                                                  2
#
#    10. In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  2

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 0 to 45
# Data columns (total 12 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   uid                                                                                                                   37 non-null     object
#  1   type                                                                                                                  37 non-null     object
#  2   1. In the last month, how often have you been upset because of something that happened unexpectedly?                  37 non-null     int64
#  3   2. In the last month, how often have you felt that you were unable to control the important things in your life?      37 non-null     int64
#  4   3. In the last month, how often have you felt nervous and "stressed"?                                                 37 non-null     int64
#  5   4. In the last month, how often have you felt confident about your ability to handle your personal problems?          37 non-null     int64
#  6   5. In the last month, how often have you felt that things were going your way?                                        37 non-null     int64
#  7   6. In the last month, how often have you found that you could not cope with all the things that you had to do?        37 non-null     int64
#  8   7. In the last month, how often have you been able to control irritations in your life?                               37 non-null     int64
#  9   8. In the last month, how often have you felt that you were on top of things?                                         37 non-null     int64
#  10  9. In the last month, how often have you been angered because of things that were outside of your control?            37 non-null     int64
#  11  10. In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?  37 non-null     int64
# dtypes: int64(10), object(2)
# memory usage: 3.8+ KB

# %%
post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 46 to 84
# Data columns (total 12 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   uid                                                                                                                   37 non-null     object
#  1   type                                                                                                                  37 non-null     object
#  2   1. In the last month, how often have you been upset because of something that happened unexpectedly?                  37 non-null     int64
#  3   2. In the last month, how often have you felt that you were unable to control the important things in your life?      37 non-null     int64
#  4   3. In the last month, how often have you felt nervous and "stressed"?                                                 37 non-null     int64
#  5   4. In the last month, how often have you felt confident about your ability to handle your personal problems?          37 non-null     int64
#  6   5. In the last month, how often have you felt that things were going your way?                                        37 non-null     int64
#  7   6. In the last month, how often have you found that you could not cope with all the things that you had to do?        37 non-null     int64
#  8   7. In the last month, how often have you been able to control irritations in your life?                               37 non-null     int64
#  9   8. In the last month, how often have you felt that you were on top of things?                                         37 non-null     int64
#  10  9. In the last month, how often have you been angered because of things that were outside of your control?            37 non-null     int64
#  11  10. In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?  37 non-null     int64
# dtypes: int64(10), object(2)
# memory usage: 3.8+ KB

# %%
pre_df.columns
# Out:
# Index(['uid', 'type',
#        '1. In the last month, how often have you been upset because of something that happened unexpectedly?',
#        '2. In the last month, how often have you felt that you were unable to control the important things in your life?',
#        '3. In the last month, how often have you felt nervous and "stressed"?',
#        '4. In the last month, how often have you felt confident about your ability to handle your personal problems?',
#        '5. In the last month, how often have you felt that things were going your way?',
#        '6. In the last month, how often have you found that you could not cope with all the things that you had to do?',
#        '7. In the last month, how often have you been able to control irritations in your life?',
#        '8. In the last month, how often have you felt that you were on top of things?',
#        '9. In the last month, how often have you been angered because of things that were outside of your control?',
#        '10. In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?'],
#       dtype='object')

# %%
pos = ['4. In the last month, how often have you felt confident about your ability to handle your personal problems?',
       '5. In the last month, how often have you felt that things were going your way?',
       '7. In the last month, how often have you been able to control irritations in your life?',
       '8. In the last month, how often have you felt that you were on top of things?',
       ]
neg = ['1. In the last month, how often have you been upset because of something that happened unexpectedly?',
       '2. In the last month, how often have you felt that you were unable to control the important things in your life?',
       '3. In the last month, how often have you felt nervous and "stressed"?',
       '6. In the last month, how often have you found that you could not cope with all the things that you had to do?',
       '9. In the last month, how often have you been angered because of things that were outside of your control?',
       '10. In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?'
       ]
diff_df = get_pos_neg_difference(pre_df, post_df, pos, neg, 'PerceivedStressScale')
diff_df.head()
# Out:
# Check uid matching in the pre and post df: True
#      PerceivedStressScale_pos_pre  PerceivedStressScale_neg_pre  \
# uid
# u00                             9                           -17
# u01                            11                           -10
# u02                             7                           -12
# u03                             4                            -5
# u04                             7                           -12
#
#      PerceivedStressScale_pos_post  PerceivedStressScale_neg_post  \
# uid
# u00                             10                             -9
# u01                             11                            -11
# u02                              9                            -18
# u03                              5                            -13
# u04                             10                            -11
#
#      PerceivedStressScale_pos_delta  PerceivedStressScale_neg_delta  \
# uid
# u00                               1                               8
# u01                               0                              -1
# u02                               2                              -6
# u03                               1                              -8
# u04                               3                               1
#
#      PerceivedStressScale_delta
# uid
# u00                           9
# u01                          -1
# u02                          -4
# u03                          -7
# u04                           4

# %%
# col_names = pre_df.columns[2:]
# diff_df = get_pre_post_difference(pre_df, post_df, col_names,'PerceivedStressScale')
# diff_df.head()

# %%
# # Mapping function
# def mapping_status(score):
#     if 0 <= score <= 13:
#         return "Low stress"
#     elif 14 <= score <= 26:
#         return "Moderate stress"
#     elif 27 <= score <= 40:
#         return "High preceived stress"
#     else:
#         return "Unknown"

# # Apply the mapping function to the scores
# diff_df = get_status(diff_df, mapping_status, 'PerceivedStressScale')
# diff_df.head()
