# %%
import numpy as np
import pandas as pd

# %%
# BigFive = pd.read_csv("../results/BigFive.csv",index_col=['uid'])
flourishing = pd.read_csv("../results/flourishing.csv",index_col=['uid'])
loneliness = pd.read_csv("../results/loneliness.csv",index_col=['uid'])
panas = pd.read_csv("../results/panas.csv",index_col=['uid'])
stress  = pd.read_csv("../results/PerceivedStressScale.csv",index_col=['uid'])
phq9 = pd.read_csv("../results/PHQ-9.csv",index_col=['uid'])
# vr12 = pd.read_csv("../results/vr_12.csv",index_col=['uid'])

# %%
summary = pd.DataFrame({'uid': ['u{:02d}'.format(i) for i in range(60)]})
summary = summary.set_index('uid').join([flourishing, loneliness, panas, stress, phq9])
summary.head()
# Out:
#      Flourishing_pre  Flourishing_post  Flourishing_delta  loneliness_pos_pre  \
# uid
# u00              NaN               NaN                NaN                33.0
# u01             45.0              46.0                1.0                37.0
# u02             46.0              44.0               -2.0                37.0
# u03             34.0              31.0               -3.0                28.0
# u04             27.0              33.0                6.0                24.0
#
#      loneliness_neg_pre  loneliness_pos_post  loneliness_neg_post  \
# uid
# u00               -18.0                 33.0                -20.0
# u01               -17.0                 37.0                -22.0
# u02               -16.0                 38.0                -13.0
# u03               -25.0                 23.0                -22.0
# u04               -27.0                 28.0                -28.0
#
#      loneliness_pos_delta  loneliness_neg_delta  loneliness_delta  ...  \
# ...

# %%
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, u00 to u59
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Flourishing_pre                 34 non-null     float64
#  1   Flourishing_post                34 non-null     float64
#  2   Flourishing_delta               34 non-null     float64
#  3   loneliness_pos_pre              37 non-null     float64
#  4   loneliness_neg_pre              37 non-null     float64
#  5   loneliness_pos_post             37 non-null     float64
#  6   loneliness_neg_post             37 non-null     float64
#  7   loneliness_pos_delta            37 non-null     float64
#  8   loneliness_neg_delta            37 non-null     float64
#  9   loneliness_delta                37 non-null     float64
#  10  panas_pos_pre                   35 non-null     float64
#  11  panas_neg_pre                   35 non-null     float64
# ...

# %%
summary.to_csv("../results/survey_summary.csv")

# %%
# Remove NaN value
col_names = summary.columns
summary.dropna(subset = col_names, inplace=True)
summary.head()
# Out:
#      Flourishing_pre  Flourishing_post  Flourishing_delta  loneliness_pos_pre  \
# uid
# u01             45.0              46.0                1.0                37.0
# u02             46.0              44.0               -2.0                37.0
# u03             34.0              31.0               -3.0                28.0
# u04             27.0              33.0                6.0                24.0
# u07             49.0              47.0               -2.0                32.0
#
#      loneliness_neg_pre  loneliness_pos_post  loneliness_neg_post  \
# uid
# u01               -17.0                 37.0                -22.0
# u02               -16.0                 38.0                -13.0
# u03               -25.0                 23.0                -22.0
# u04               -27.0                 28.0                -28.0
# u07               -21.0                 34.0                -24.0
#
#      loneliness_pos_delta  loneliness_neg_delta  loneliness_delta  ...  \
# ...

# %%
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, u01 to u59
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Flourishing_pre                 25 non-null     float64
#  1   Flourishing_post                25 non-null     float64
#  2   Flourishing_delta               25 non-null     float64
#  3   loneliness_pos_pre              25 non-null     float64
#  4   loneliness_neg_pre              25 non-null     float64
#  5   loneliness_pos_post             25 non-null     float64
#  6   loneliness_neg_post             25 non-null     float64
#  7   loneliness_pos_delta            25 non-null     float64
#  8   loneliness_neg_delta            25 non-null     float64
#  9   loneliness_delta                25 non-null     float64
#  10  panas_pos_pre                   25 non-null     float64
#  11  panas_neg_pre                   25 non-null     float64
# ...

# %%
summary.to_csv("../results/survey_summary_reduced.csv")
