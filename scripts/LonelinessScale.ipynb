# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.pre_post_loader import pre_post_reader, get_pre_post_difference

# %% [markdown]
# # Data Processing
# ## 1. Read data
# - Data missing (40 uids)

# %%
data_path = '/Users/catherine/AI/UoA/T6/RA/code/StudentLife/data/dataset/survey/LonelinessScale.csv'
# define a mapping function
mapping_rule = [{
        'Never': int(1),
        'Rarely': int(2),
        'Sometimes': int(3),
        'Often': int(4)
    }]
# Remove the row wtih NaN value
df, pre_df, post_df = pre_post_reader(data_path, mode='remove', mapping=mapping_rule)

# %%
df.head()
# Out:
#    uid type  1. I feel in tune with the people around me  \
# 0  u00  pre                                            3
# 1  u01  pre                                            3
# 2  u02  pre                                            3
# 3  u03  pre                                            3
# 4  u04  pre                                            3
#
#    2. I lack companionship  3. There is no one I can turn to  \
# 0                        2                                 1
# 1                        2                                 2
# 2                        2                                 2
# 3                        2                                 1
# 4                        3                                 3
#
#    4. I do not feel alone  5. I feel part of a group of friends  \
# 0                       1                                     4
# 1                       3                                     4
# ...

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 0 to 45
# Data columns (total 22 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   uid                                                          37 non-null     object
#  1   type                                                         37 non-null     object
#  2   1. I feel in tune with the people around me                  37 non-null     int64
#  3   2. I lack companionship                                      37 non-null     int64
#  4   3. There is no one I can turn to                             37 non-null     int64
#  5   4. I do not feel alone                                       37 non-null     int64
#  6   5. I feel part of a group of friends                         37 non-null     int64
# ...

# %%
post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 46 to 82
# Data columns (total 22 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   uid                                                          37 non-null     object
#  1   type                                                         37 non-null     object
#  2   1. I feel in tune with the people around me                  37 non-null     int64
#  3   2. I lack companionship                                      37 non-null     int64
#  4   3. There is no one I can turn to                             37 non-null     int64
#  5   4. I do not feel alone                                       37 non-null     int64
#  6   5. I feel part of a group of friends                         37 non-null     int64
# ...

# %%
col_names = pre_df.columns[2:]
diff_df = get_pre_post_difference(pre_df, post_df, col_names,'loneliness')
diff_df.head()
# Out:
# Check uid matching in the pre and post df: True
#      loneliness_pre  loneliness_post  loneliness_delta
# uid
# u52              59               49                10
# u03              53               45                 8
# u33              59               66                 7
# u18              58               51                 7
# u10              53               47                 6
