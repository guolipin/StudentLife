# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.pre_post_loader import pre_post_reader,get_pre_post_difference

# %% [markdown]
# # Data Processing
# ## 1. Read data
# - Data missing (40 uids)

# %%
data_path = '/Users/catherine/AI/UoA/T6/RA/code/StudentLife/data/dataset/survey/FlourishingScale.csv'
# Remove the row wtih NaN value
df, pre_df, post_df = pre_post_reader(data_path, mode='remove', to_int=True)
# Out:
# /Users/catherine/AI/UoA/T6/RA/code/StudentLife/src/pre_post_loader.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[col_names[2:]] = new_df.loc[:, col_names[2:]].astype('int64')

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 1 to 45
# Data columns (total 10 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   uid                                                                    34 non-null     object
#  1   type                                                                   34 non-null     object
#  2   I lead a purposeful and meaningful life                                34 non-null     int64
#  3   My social relationships are supportive and rewarding                   34 non-null     int64
#  4   I am engaged and interested in my daily activities                     34 non-null     int64
#  5   I actively contribute to the happiness and well-being of others        34 non-null     int64
# ...

# %%
post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 47 to 82
# Data columns (total 10 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   uid                                                                    34 non-null     object
#  1   type                                                                   34 non-null     object
#  2   I lead a purposeful and meaningful life                                34 non-null     int64
#  3   My social relationships are supportive and rewarding                   34 non-null     int64
#  4   I am engaged and interested in my daily activities                     34 non-null     int64
#  5   I actively contribute to the happiness and well-being of others        34 non-null     int64
# ...

# %%
col_names = pre_df.columns[2:]
diff_df = get_pre_post_difference(pre_df, post_df,col_names,'flourishing')
diff_df
# Out:
# Check uid matching in the pre and post df: True
#      flourishing_pre  flourishing_post  flourishing_delta
# uid
# u42               45                16                 29
# u34               49                23                 26
# u31               16                36                 20
# u59               43                50                  7
# u23               35                42                  7
# u44               48                41                  7
# u04               27                33                  6
# u43               47                42                  5
# u15               43                48                  5
# u49               51                55                  4
# u35               48                44                  4
# u30               52                56                  4
# u33               31                28                  3
# u52               34                37                  3
# ...

# %%
# Replace the NaN value to 0
# df2, pre_df2, post_df2 = pre_post_reader(data_path, mode='replace', to_int=True)
# diff_df2 = get_difference(pre_df2,post_df2,col_names)
# diff_df2.head()
