# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.pre_post_loader import pre_post_reader, get_pre_post_difference

# %% [markdown]
# # Data Processing
# ## 1. Read data
# - Data missing (40 uids)

# %%
data_path = '/Users/catherine/AI/UoA/T6/RA/code/StudentLife/data/dataset/survey/vr_12.csv'
# define a mapping function
rules = [
    { #Q1
    'Excellent': int(1),
    'Very good': int(2), 
    'Good': int(3), 
    'Fair': int(4),
    "Poor": int(5)},
    { #Q2a, 2b
    'Yes, limited a lot': int(1),
    'Yes, limited a little': int(2),
    'No, not limited at all': int(3)},
    { #Q3a, 3b, 4a, 4b
    'No, none of the time': int(1),
    'Yes, a little of the time': int(2),
    'Yes, some of the time': int(3),
    'Yes, most of the time': int(4),
    'Yes, all of the time': int(5),},
    { #Q5
    'Not at all': int(1), 
    'A little bit': int(2), 
    'Moderately': int(3),
    'Quite a bit': int(4), 
    'Extremely': int(5),},
    { #Q6a, 6b, 6c
    'All of the time': int(1),
    'Most of the time': int(2),
    'A good bit of the time': int(3), 
    'Some of the time': int(4),
    'A little of the time': int(5), 
    'None of the time': int(6), },
    { #Q7
    'All of the time': int(1),
    'Most of the time': int(2),
    'Some of the time': int(3),
    'A little of the time': int(4), 
    'None of the time': int(5)},
    { #Q8, Q9
    'Much better':int(1),
    'Slightly better': int(2),
    'About the same':int(3),
    'Slightly worse':int(4),
    'Much worse':int(5)
    }]
mapping_rules = [rules[0],rules[1], rules[1], rules[2], rules[2],rules[2],rules[2],rules[3], rules[4],rules[4],rules[4],rules[5], rules[6],rules[6]]

# %%
# # Remove the row wtih NaN value
df, pre_df, post_df = pre_post_reader(data_path, mode='remove', mapping=mapping_rules)

# %%
df.head()
# Out:
#    uid type  In general, would you say your health is  \
# 0  u00  pre                                         2
# 1  u01  pre                                         1
# 2  u02  pre                                         3
# 3  u03  pre                                         2
# 4  u04  pre                                         2
#
#    Moderate activities, such as moving a table, pushing a vacuum cleaner, bowling or playing golf?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    Climbing several flights of stairs?  \
# 0                                    3
# 1                                    3
# 2                                    3
# 3                                    3
# 4                                    3
#
# ...

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 0 to 45
# Data columns (total 16 columns):
#  #   Column                                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                                              --------------  -----
#  0   uid                                                                                                                                                                                 37 non-null     object
#  1   type                                                                                                                                                                                37 non-null     object
# ...

# %%
post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 46 to 82
# Data columns (total 16 columns):
#  #   Column                                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                                              --------------  -----
#  0   uid                                                                                                                                                                                 37 non-null     object
#  1   type                                                                                                                                                                                37 non-null     object
# ...

# %%
col_names = pre_df.columns[2:-2]
diff_df = get_pre_post_difference(pre_df, post_df, col_names, 'vr_12')
diff_df.head()
# Out:
# Check uid matching in the pre and post df: True
#      vr_12_pre  vr_12_post  vr_12_delta
# uid
# u27       28.0        42.0         14.0
# u17       38.0        47.0          9.0
# u31       38.0        30.0          8.0
# u16       30.0        37.0          7.0
# u56       37.0        31.0          6.0
