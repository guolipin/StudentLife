# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.pre_post_loader import pre_post_reader, get_pre_post_difference

# %% [markdown]
# # Data Processing
# ## 1. Read data
# - Data missing (40 uids)

# %%
data_path = '/Users/catherine/AI/UoA/T6/RA/code/StudentLife/data/dataset/survey/psqi.csv'
cols = ['uid', 'type',
       'During the past month, what time have you usually gone to bed at night? ',
       'During the past month, how long (in minutes) has it usually taken you to fall asleep each night?',
       'When have you usually gotten up in the morning?',
       'During the past month, how many hours of actual sleep did you get at night? (This may be different than the number of hours you spent in bed.)',
       'a. Cannot get to sleep within 30 minutes',
       'b. Wake up in the middle of the night or early morning',
       'c. Have to get up to use the bathroom',
       'd. Cannot breathe comfortably', 'e. Cough or snore loudly',
       'f. Feel too cold', 'g. Feel too hot', 'h. Have bad dreams',
       'i. Have pain', 'j. Other reason(s)',
    #    'Other reason(s), please describe, including how often you have had trouble sleeping because of this reason(s):',
       'During the past month, how often have you taken medicine (prescribed or over the counter) to help you sleep?',
       'During the past month, how often have you had trouble staying awake while driving, eating meals, or engaging in social activity?',
       'During the past month, how much of a problem has it been for you to keep up enthusiasm to get things done?',
       'During the past month, how would you rate your sleep quality overall?']

# %%
# define a mapping function
# mapping_rule = {
#         'Not at all': int(0),
#         'Several days': int(1),
#         'More than half the days': int(2),
#         'Nearly every day': int(3)
#     }

# %%
# Remove the row wtih NaN value
df, pre_df, post_df = pre_post_reader(data_path, select_cols=cols, mode='remove', mapping=None)
df.head()
# Out:
#    uid type  \
# 1  u01  pre
# 2  u02  pre
# 3  u03  pre
# 5  u05  pre
# 6  u07  pre
#
#   During the past month, what time have you usually gone to bed at night?   \
# 1                                                1AM
# 2                                        around 1 am
# 3                                                1am
# 5                                            11:30pm
# 6                                 Between 12a and 2a
#
#   During the past month, how long (in minutes) has it usually taken you to fall asleep each night?  \
# 1                                                 20
# 2    I fall asleep really quickly, maybe 5-10minutes
# 3                                              10min
# 5                                                 15
# 6                                         20 minutes
#
#   When have you usually gotten up in the morning?  \
# 1                                            11AM
# 2                                       about 9am
# 3                                          8:30am
# 5                                          8:00am
# 6                              between 9a and 11a
#
#   During the past month, how many hours of actual sleep did you get at night? (This may be different than the number of hours you spent in bed.)  \
# 1                                             10-Sep
# 2                                     about 7-8hours
# 3                                             7hours
# 5                                                  8
# 6                                                  8
#
#   a. Cannot get to sleep within 30 minutes  \
# 1                Not during the past month
# 2                Not during the past month
# 3                Not during the past month
# 5                      Less than once week
# 6                     Once or a twice week
#
#   b. Wake up in the middle of the night or early morning  \
# 1                         Three or a more times week
# 2                          Not during the past month
# 3                          Not during the past month
# 5                                Less than once week
# 6                          Not during the past month
#
#   c. Have to get up to use the bathroom d. Cannot breathe comfortably  \
# 1             Not during the past month     Not during the past month
# 2             Not during the past month     Not during the past month
# 3             Not during the past month     Not during the past month
# 5                   Less than once week     Not during the past month
# 6             Not during the past month     Not during the past month
#
#     e. Cough or snore loudly           f. Feel too cold  \
# 1  Not during the past month       Once or a twice week
# 2  Not during the past month        Less than once week
# 3  Not during the past month  Not during the past month
# 5  Not during the past month  Not during the past month
# 6  Not during the past month  Not during the past month
#
#              g. Feel too hot         h. Have bad dreams  \
# 1       Once or a twice week        Less than once week
# 2  Not during the past month  Not during the past month
# 3  Not during the past month        Less than once week
# 5       Once or a twice week  Not during the past month
# 6  Not during the past month        Less than once week
#
#                 i. Have pain         j. Other reason(s)  \
# 1  Not during the past month  Not during the past month
# 2  Not during the past month  Not during the past month
# 3  Not during the past month  Not during the past month
# 5  Not during the past month  Not during the past month
# 6        Less than once week  Not during the past month
#
#   During the past month, how often have you taken medicine (prescribed or over the counter) to help you sleep?  \
# 1                                Less than once week
# 2                          Not during the past month
# 3                          Not during the past month
# 5                          Not during the past month
# 6                          Not during the past month
#
#   During the past month, how often have you had trouble staying awake while driving, eating meals, or engaging in social activity?  \
# 1                               Once or a twice week
# 2                               Once or a twice week
# 3                                Less than once week
# 5                                Less than once week
# 6                               Once or a twice week
#
#   During the past month, how much of a problem has it been for you to keep up enthusiasm to get things done?  \
# 1                               Once or a twice week
# 2                               Once or a twice week
# 3                                Less than once week
# 5                          Not during the past month
# 6                               Once or a twice week
#
#   During the past month, how would you rate your sleep quality overall?
# 1                                          Very good
# 2                                        Fairly good
# 3                                        Fairly good
# 5                                          Very good
# 6                                        Fairly good

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 1 to 42
# Data columns (total 20 columns):
#  #   Column                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                          --------------  -----
#  0   uid                                                                                                                                             24 non-null     object
#  1   type                                                                                                                                            24 non-null     object
#  2   During the past month, what time have you usually gone to bed at night?                                                                         24 non-null     object
#  3   During the past month, how long (in minutes) has it usually taken you to fall asleep each night?                                                24 non-null     object
#  4   When have you usually gotten up in the morning?                                                                                                 24 non-null     object
#  5   During the past month, how many hours of actual sleep did you get at night? (This may be different than the number of hours you spent in bed.)  24 non-null     object
#  6   a. Cannot get to sleep within 30 minutes                                                                                                        24 non-null     object
#  7   b. Wake up in the middle of the night or early morning                                                                                          24 non-null     object
#  8   c. Have to get up to use the bathroom                                                                                                           24 non-null     object
#  9   d. Cannot breathe comfortably                                                                                                                   24 non-null     object
#  10  e. Cough or snore loudly                                                                                                                        24 non-null     object
#  11  f. Feel too cold                                                                                                                                24 non-null     object
#  12  g. Feel too hot                                                                                                                                 24 non-null     object
#  13  h. Have bad dreams                                                                                                                              24 non-null     object
#  14  i. Have pain                                                                                                                                    24 non-null     object
#  15  j. Other reason(s)                                                                                                                              24 non-null     object
#  16  During the past month, how often have you taken medicine (prescribed or over the counter) to help you sleep?                                    24 non-null     object
#  17  During the past month, how often have you had trouble staying awake while driving, eating meals, or engaging in social activity?                24 non-null     object
#  18  During the past month, how much of a problem has it been for you to keep up enthusiasm to get things done?                                      24 non-null     object
#  19  During the past month, how would you rate your sleep quality overall?                                                                           24 non-null     object
# dtypes: object(20)
# memory usage: 3.9+ KB

# %%
post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 47 to 82
# Data columns (total 20 columns):
#  #   Column                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                          --------------  -----
#  0   uid                                                                                                                                             24 non-null     object
#  1   type                                                                                                                                            24 non-null     object
#  2   During the past month, what time have you usually gone to bed at night?                                                                         24 non-null     object
#  3   During the past month, how long (in minutes) has it usually taken you to fall asleep each night?                                                24 non-null     object
#  4   When have you usually gotten up in the morning?                                                                                                 24 non-null     object
#  5   During the past month, how many hours of actual sleep did you get at night? (This may be different than the number of hours you spent in bed.)  24 non-null     object
#  6   a. Cannot get to sleep within 30 minutes                                                                                                        24 non-null     object
#  7   b. Wake up in the middle of the night or early morning                                                                                          24 non-null     object
#  8   c. Have to get up to use the bathroom                                                                                                           24 non-null     object
#  9   d. Cannot breathe comfortably                                                                                                                   24 non-null     object
#  10  e. Cough or snore loudly                                                                                                                        24 non-null     object
#  11  f. Feel too cold                                                                                                                                24 non-null     object
#  12  g. Feel too hot                                                                                                                                 24 non-null     object
#  13  h. Have bad dreams                                                                                                                              24 non-null     object
#  14  i. Have pain                                                                                                                                    24 non-null     object
#  15  j. Other reason(s)                                                                                                                              24 non-null     object
#  16  During the past month, how often have you taken medicine (prescribed or over the counter) to help you sleep?                                    24 non-null     object
#  17  During the past month, how often have you had trouble staying awake while driving, eating meals, or engaging in social activity?                24 non-null     object
#  18  During the past month, how much of a problem has it been for you to keep up enthusiasm to get things done?                                      24 non-null     object
#  19  During the past month, how would you rate your sleep quality overall?                                                                           24 non-null     object
# dtypes: object(20)
# memory usage: 3.9+ KB

# %%
pre_df.columns
# Out:
# Index(['uid', 'type',
#        'During the past month, what time have you usually gone to bed at night? ',
#        'During the past month, how long (in minutes) has it usually taken you to fall asleep each night?',
#        'When have you usually gotten up in the morning?',
#        'During the past month, how many hours of actual sleep did you get at night? (This may be different than the number of hours you spent in bed.)',
#        'a. Cannot get to sleep within 30 minutes',
#        'b. Wake up in the middle of the night or early morning',
#        'c. Have to get up to use the bathroom',
#        'd. Cannot breathe comfortably', 'e. Cough or snore loudly',
#        'f. Feel too cold', 'g. Feel too hot', 'h. Have bad dreams',
#        'i. Have pain', 'j. Other reason(s)',
#        'During the past month, how often have you taken medicine (prescribed or over the counter) to help you sleep?',
#        'During the past month, how often have you had trouble staying awake while driving, eating meals, or engaging in social activity?',
#        'During the past month, how much of a problem has it been for you to keep up enthusiasm to get things done?',
#        'During the past month, how would you rate your sleep quality overall?'],
#       dtype='object')

# %%
col_names = pre_df.columns[2:-2]
diff_df = get_difference(pre_df, post_df, col_names)
diff_df.head()
# Out:
# Check uid matching in the pre and post df: True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/computation/expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/catherine/AI/UoA/T6/RA/code/StudentLife/scripts/psqi.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/Users/catherine/AI/UoA/T6/RA/code/StudentLife/scripts/psqi.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> col_names = pre_df.columns[2:-2]
# ----> <a href='vscode-notebook-cell:/Users/catherine/AI/UoA/T6/RA/code/StudentLife/scripts/psqi.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> diff_df = get_difference(pre_df, post_df, col_names)
#       <a href='vscode-notebook-cell:/Users/catherine/AI/UoA/T6/RA/code/StudentLife/scripts/psqi.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> diff_df.head()
#
# File ~/AI/UoA/T6/RA/code/StudentLife/src/pre_post_loader.py:44, in get_difference(pre_df, post_df, col_names)
#      42 print('Check uid matching in the pre and post df:', pre_df['uid'].tolist() == post_df['uid'].tolist())
#      43 diff_df = pd.DataFrame({'pre_sum':sum1, 'post_sum':sum2}, index=pre_df['uid'])
# ---> 44 diff_df['delta'] = abs(diff_df['post_sum'] - diff_df['pre_sum'])
#      45 diff_df.sort_values(by=['delta'],ascending=False, inplace=True)
#      46 return diff_df
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File ~/anaconda3/envs/student/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:116, in _masked_arith_op(x, y, op)
#     114     # See GH#5284, GH#5035, GH#19448 for historical reference
#     115     if mask.any():
# --> 116         result[mask] = op(xrav[mask], yrav[mask])
#     118 else:
#     119     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
